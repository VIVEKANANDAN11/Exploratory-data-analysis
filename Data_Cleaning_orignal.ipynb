# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlp
import seaborn as sns
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-15fb62b6-b30f-4a94-8c0d-c6e476efb49e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15fb62b6-b30f-4a94-8c0d-c6e476efb49e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data
# Out:
# {'Original.csv': b'date,[PS01=SLC03] Electrical conductivity (EC) [\xc2\xb5S/cm],[PS02] Electrical conductivity (EC) [\xc2\xb5S/cm],[PS03] Electrical conductivity (EC) [\xc2\xb5S/cm],[PS04] Electrical conductivity (EC) [\xc2\xb5S/cm],[SLC01] Electrical conductivity (EC) [\xc2\xb5S/cm],[SLC02] Electrical conductivity (EC) [\xc2\xb5S/cm],[PS01=SLC03] Nitrite (NO2-N) [mg NO2-N/L],[PS02] Nitrite (NO2-N) [mg NO2-N/L],[PS03] Nitrite (NO2-N) [mg NO2-N/L],[PS04] Nitrite (NO2-N) [mg NO2-N/L],[SLC01] Nitrite (NO2-N) [mg NO2-N/L],[SLC02] Nitrite (NO2-N) [mg NO2-N/L],[PS01=SLC03] Nitrate (NO3-N) [mg NO3-N/L],[PS02] Nitrate (NO3-N) [mg NO3-N/L],[PS03] Nitrate (NO3-N) [mg NO3-N/L],[PS04] Nitrate (NO3-N) [mg NO3-N/L],[SLC01] Nitrate (NO3-N) [mg NO3-N/L],[SLC02] Nitrate (NO3-N) [mg NO3-N/L],[PS01=SLC03] Total Nitrogen (TN) [mg N/L],[PS02] Total Nitrogen (TN) [mg N/L],[PS03] Total Nitrogen (TN) [mg N/L],[PS04] Total Nitrogen (TN) [mg N/L],[SLC01] Total Nitrogen (TN) [mg N/L],[SLC02] Total Nitrogen (T
# ...

# %%
df=pd.read_csv('Original.csv')
df
# Out:
#           date  [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  \
# 0   2014-01-31                                              301.2
# 1   2014-02-28                                                NaN
# 2   2014-03-31                                              204.6
# 3   2014-04-30                                                NaN
# 4   2014-05-31                                              187.3
# ..         ...                                                ...
# 75  2020-04-30                                              416.1
# 76  2020-05-31                                                NaN
# 77  2020-06-30                                                NaN
# 78  2020-07-31                                                NaN
# 79  2020-08-31                                                NaN
#
#     [PS02] Electrical conductivity (EC) [µS/cm]  \
# 0                                         240.6
# 1                                           NaN
# ...

# %%
df.shape
# Out:
# (80, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 49 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   date                                               80 non-null     object
#  1   [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  28 non-null     float64
#  2   [PS02] Electrical conductivity (EC) [µS/cm]        32 non-null     float64
#  3   [PS03] Electrical conductivity (EC) [µS/cm]        32 non-null     float64
#  4   [PS04] Electrical conductivity (EC) [µS/cm]        32 non-null     float64
#  5   [SLC01] Electrical conductivity (EC) [µS/cm]       37 non-null     float64
#  6   [SLC02] Electrical conductivity (EC) [µS/cm]       37 non-null     float64
#  7   [PS01=SLC03] Nitrite (NO2-N) [mg NO2-N/L]          28 non-null     float64
# ...

# %%
df.head()
# Out:
#          date  [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  \
# 0  2014-01-31                                              301.2
# 1  2014-02-28                                                NaN
# 2  2014-03-31                                              204.6
# 3  2014-04-30                                                NaN
# 4  2014-05-31                                              187.3
#
#    [PS02] Electrical conductivity (EC) [µS/cm]  \
# 0                                        240.6
# 1                                          NaN
# 2                                        142.8
# 3                                          NaN
# 4                                        132.3
#
#    [PS03] Electrical conductivity (EC) [µS/cm]  \
# 0                                        239.8
# 1                                          NaN
# 2                                        182.9
# 3                                          NaN
# ...

# %%
df.tail()
# Out:
#           date  [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  \
# 75  2020-04-30                                              416.1
# 76  2020-05-31                                                NaN
# 77  2020-06-30                                                NaN
# 78  2020-07-31                                                NaN
# 79  2020-08-31                                                NaN
#
#     [PS02] Electrical conductivity (EC) [µS/cm]  \
# 75                                          NaN
# 76                                          NaN
# 77                                          NaN
# 78                                          NaN
# 79                                          NaN
#
#     [PS03] Electrical conductivity (EC) [µS/cm]  \
# 75                                          NaN
# 76                                          NaN
# 77                                          NaN
# 78                                          NaN
# ...

# %%
df.describe()
# Out:
#        [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  \
# count                                          28.000000
# mean                                          269.528571
# std                                            93.911053
# min                                            81.000000
# 25%                                           221.175000
# 50%                                           272.300000
# 75%                                           329.275000
# max                                           437.500000
#
#        [PS02] Electrical conductivity (EC) [µS/cm]  \
# count                                    32.000000
# mean                                    169.500000
# std                                      53.684076
# min                                      66.800000
# 25%                                     138.050000
# 50%                                     166.450000
# 75%                                     206.775000
# ...

# %%
df.columns
# Out:
# Index(['date', '[PS01=SLC03] Electrical conductivity (EC) [µS/cm]',
#        '[PS02] Electrical conductivity (EC) [µS/cm]',
#        '[PS03] Electrical conductivity (EC) [µS/cm]',
#        '[PS04] Electrical conductivity (EC) [µS/cm]',
#        '[SLC01] Electrical conductivity (EC) [µS/cm]',
#        '[SLC02] Electrical conductivity (EC) [µS/cm]',
#        '[PS01=SLC03] Nitrite (NO2-N) [mg NO2-N/L]',
#        '[PS02] Nitrite (NO2-N) [mg NO2-N/L]',
#        '[PS03] Nitrite (NO2-N) [mg NO2-N/L]',
#        '[PS04] Nitrite (NO2-N) [mg NO2-N/L]',
#        '[SLC01] Nitrite (NO2-N) [mg NO2-N/L]',
#        '[SLC02] Nitrite (NO2-N) [mg NO2-N/L]',
#        '[PS01=SLC03] Nitrate (NO3-N) [mg NO3-N/L]',
#        '[PS02] Nitrate (NO3-N) [mg NO3-N/L]',
#        '[PS03] Nitrate (NO3-N) [mg NO3-N/L]',
#        '[PS04] Nitrate (NO3-N) [mg NO3-N/L]',
#        '[SLC01] Nitrate (NO3-N) [mg NO3-N/L]',
#        '[SLC02] Nitrate (NO3-N) [mg NO3-N/L]',
#        '[PS01=SLC03] Total Nitrogen (TN) [mg N/L]',
# ...

# %%
df.isnull().sum()
# Out:
# date                                                  0
# [PS01=SLC03] Electrical conductivity (EC) [µS/cm]    52
# [PS02] Electrical conductivity (EC) [µS/cm]          48
# [PS03] Electrical conductivity (EC) [µS/cm]          48
# [PS04] Electrical conductivity (EC) [µS/cm]          48
# [SLC01] Electrical conductivity (EC) [µS/cm]         43
# [SLC02] Electrical conductivity (EC) [µS/cm]         43
# [PS01=SLC03] Nitrite (NO2-N) [mg NO2-N/L]            52
# [PS02] Nitrite (NO2-N) [mg NO2-N/L]                  48
# [PS03] Nitrite (NO2-N) [mg NO2-N/L]                  50
# [PS04] Nitrite (NO2-N) [mg NO2-N/L]                  49
# [SLC01] Nitrite (NO2-N) [mg NO2-N/L]                 43
# [SLC02] Nitrite (NO2-N) [mg NO2-N/L]                 43
# [PS01=SLC03] Nitrate (NO3-N) [mg NO3-N/L]            52
# [PS02] Nitrate (NO3-N) [mg NO3-N/L]                  48
# [PS03] Nitrate (NO3-N) [mg NO3-N/L]                  49
# [PS04] Nitrate (NO3-N) [mg NO3-N/L]                  49
# ...

# %%
df.isnull().mean()
# Out:
# date                                                 0.0000
# [PS01=SLC03] Electrical conductivity (EC) [µS/cm]    0.6500
# [PS02] Electrical conductivity (EC) [µS/cm]          0.6000
# [PS03] Electrical conductivity (EC) [µS/cm]          0.6000
# [PS04] Electrical conductivity (EC) [µS/cm]          0.6000
# [SLC01] Electrical conductivity (EC) [µS/cm]         0.5375
# [SLC02] Electrical conductivity (EC) [µS/cm]         0.5375
# [PS01=SLC03] Nitrite (NO2-N) [mg NO2-N/L]            0.6500
# [PS02] Nitrite (NO2-N) [mg NO2-N/L]                  0.6000
# [PS03] Nitrite (NO2-N) [mg NO2-N/L]                  0.6250
# [PS04] Nitrite (NO2-N) [mg NO2-N/L]                  0.6125
# [SLC01] Nitrite (NO2-N) [mg NO2-N/L]                 0.5375
# [SLC02] Nitrite (NO2-N) [mg NO2-N/L]                 0.5375
# [PS01=SLC03] Nitrate (NO3-N) [mg NO3-N/L]            0.6500
# [PS02] Nitrate (NO3-N) [mg NO3-N/L]                  0.6000
# [PS03] Nitrate (NO3-N) [mg NO3-N/L]                  0.6125
# ...

# %%
subset=df.fillna(df.mean().iloc[0])
subset
# Out:
# <ipython-input-29-e28de765b28c>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   subset=df.fillna(df.mean().iloc[0])
#           date  [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  \
# 0   2014-01-31                                         301.200000
# 1   2014-02-28                                         269.528571
# 2   2014-03-31                                         204.600000
# 3   2014-04-30                                         269.528571
# 4   2014-05-31                                         187.300000
# ..         ...                                                ...
# 75  2020-04-30                                         416.100000
# 76  2020-05-31                                         269.528571
# ...

# %%
df=df.dropna()
df
# Out:
#           date  [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  \
# 0   2014-01-31                                              301.2
# 6   2014-07-31                                               81.0
# 8   2014-09-30                                              155.5
# 22  2015-11-30                                              344.8
# 24  2016-01-31                                              266.9
# 33  2016-10-31                                              328.6
# 37  2017-02-28                                              245.7
# 39  2017-04-30                                              331.3
# 45  2017-10-31                                              288.9
# 47  2017-12-31                                              410.5
# 49  2018-02-28                                              238.9
# 53  2018-06-30                                              277.7
# 55  2018-08-31                                              226.7
# ...

# %%
a = df.copy()

# %%
a
# Out:
#           date  [PS01=SLC03] Electrical conductivity (EC) [µS/cm]  \
# 0   2014-01-31                                              301.2
# 6   2014-07-31                                               81.0
# 8   2014-09-30                                              155.5
# 22  2015-11-30                                              344.8
# 24  2016-01-31                                              266.9
# 33  2016-10-31                                              328.6
# 37  2017-02-28                                              245.7
# 39  2017-04-30                                              331.3
# 45  2017-10-31                                              288.9
# 47  2017-12-31                                              410.5
# 49  2018-02-28                                              238.9
# 53  2018-06-30                                              277.7
# 55  2018-08-31                                              226.7
# ...
