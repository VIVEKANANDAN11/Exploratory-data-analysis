# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-81ceb3d5-19db-4b58-835d-17c886dc71a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81ceb3d5-19db-4b58-835d-17c886dc71a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data
# Out:
# {'nba.csv': b"Name,Team,Number,Position,Age,Height,Weight,College,Salary\r\nAvery Bradley,Boston Celtics,0,PG,25,2-Jun,180,Texas,7730337\r\nJae Crowder,Boston Celtics,99,SF,25,6-Jun,235,Marquette,6796117\r\nJohn Holland,Boston Celtics,30,SG,27,5-Jun,205,Boston University,\r\nR.J. Hunter,Boston Celtics,28,SG,22,5-Jun,185,Georgia State,1148640\r\nJonas Jerebko,Boston Celtics,8,PF,29,10-Jun,231,,5000000\r\nAmir Johnson,Boston Celtics,90,PF,29,9-Jun,240,,12000000\r\nJordan Mickey,Boston Celtics,55,PF,21,8-Jun,235,LSU,1170960\r\nKelly Olynyk,Boston Celtics,41,C,25,Jul-00,238,Gonzaga,2165160\r\nTerry Rozier,Boston Celtics,12,PG,22,2-Jun,190,Louisville,1824360\r\nMarcus Smart,Boston Celtics,36,PG,22,4-Jun,220,Oklahoma State,3431040\r\nJared Sullinger,Boston Celtics,7,C,24,9-Jun,260,Ohio State,2569260\r\nIsaiah Thomas,Boston Celtics,4,PG,27,9-May,185,Washington,6912869\r\nEvan Turner,Boston Celtics,11,SG,27,7-Jun,220,Ohio State,3425510\r\nJames Young,Boston Celtics,13,SG,20,6-Jun,215,Kentuck
# ...

# %%
df=pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.shape
# Out:
# (457, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df2=df.copy()
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.loc[1:4]
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.loc[1:4,'Team':'College']
# Out:
#              Team  Number Position  Age  Height  Weight            College
# 1  Boston Celtics      99       SF   25   6-Jun     235          Marquette
# 2  Boston Celtics      30       SG   27   5-Jun     205  Boston University
# 3  Boston Celtics      28       SG   22   5-Jun     185      Georgia State
# 4  Boston Celtics       8       PF   29  10-Jun     231                NaN

# %%
df.iloc[1:4,2:6]
# Out:
#    Number Position  Age Height
# 1      99       SF   25  6-Jun
# 2      30       SG   27  5-Jun
# 3      28       SG   22  5-Jun

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
subset=df.iloc[0:6,1:3]
subset
# Out:
#              Team  Number
# 0  Boston Celtics       0
# 1  Boston Celtics      99
# 2  Boston Celtics      30
# 3  Boston Celtics      28
# 4  Boston Celtics       8
# 5  Boston Celtics      90

# %%
df.head(6)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# 5   Amir Johnson  Boston Celtics      90       PF   29   9-Jun     240
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# 4                NaN   5000000.0
# 5                NaN  12000000.0

# %%
df.tail(6)
# Out:
#               Name       Team  Number Position  Age  Height  Weight   College  \
# 451  Chris Johnson  Utah Jazz      23       SF   26   6-Jun     206    Dayton
# 452     Trey Lyles  Utah Jazz      41       PF   20  10-Jun     234  Kentucky
# 453   Shelvin Mack  Utah Jazz       8       PG   26   3-Jun     203    Butler
# 454      Raul Neto  Utah Jazz      25       PG   24   1-Jun     179       NaN
# 455   Tibor Pleiss  Utah Jazz      21        C   26   3-Jul     256       NaN
# 456    Jeff Withey  Utah Jazz      24        C   26  Jul-00     231    Kansas
#
#         Salary
# 451   981348.0
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df['Salary'].quantile(0.5)
# Out:
# 2839073.0

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.isnull().mean()
# Out:
# Name        0.000000
# Team        0.000000
# Number      0.000000
# Position    0.000000
# Age         0.000000
# Height      0.000000
# Weight      0.000000
# College     0.183807
# Salary      0.024070
# dtype: float64

# %%
df.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
df.isnull().count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     457
# Salary      457
# dtype: int64

# %%
df2 = df.dropna()
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21   8-Jun     235
# 7     Kelly Olynyk  Boston Celtics      41        C   25  Jul-00     238
# ..             ...             ...     ...      ...  ...     ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23   8-Jun     206
# 451  Chris Johnson       Utah Jazz      23       SF   26   6-Jun     206
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df2.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum(axis=0) # To know the null value in the column
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.isnull().sum(axis=1) # To know the null value in the record
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 452    0
# 453    0
# 454    1
# 455    1
# 456    0
# Length: 457, dtype: int64

# %%
u=df.head(3)
u
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  5-Jun     205
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
u.replace('Y',100)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  5-Jun     205
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
r=df.replace(to_replace=np.nan,value=89)  # To replace a Nan value in entire schema
r
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
r=df['Salary'].replace(to_replace=np.nan,value=89)  # To replace a Nan value in perticular column
r
# Out:
# 0      7730337.0
# 1      6796117.0
# 2           89.0
# 3      1148640.0
# 4      5000000.0
#          ...
# 452    2239800.0
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# Name: Salary, Length: 457, dtype: float64
